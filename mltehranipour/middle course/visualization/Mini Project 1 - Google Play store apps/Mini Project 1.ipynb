# %% [markdown]
# <img src="https://webna.ir/wp-content/uploads/2018/08/%D9%85%DA%A9%D8%AA%D8%A8-%D8%AE%D9%88%D9%86%D9%87.png" width=50% />

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 align="center">Machine Learning in Python</h1>
#     <h3 align="center">Mini Project1</h3>
# </div>

# %% [markdown]
# <img src = "https://www.cyclonis.com/images/2020/03/googleplay.jpg" width=50%>

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load and Prepare Data

# %%
googleplaystore = pd.read_csv('googleplaystore.csv')
googleplaystore.sample(10)
# Out:
#                                                    App            Category  \
# 8026                       Hallmark Channel Everywhere              FAMILY
# 2493                               Youper - AI Therapy             MEDICAL
# 8416                         Toys Defense: Horror Land              FAMILY
# 9366                                               EH!           LIFESTYLE
# 8028                                  News 8 San Diego  NEWS_AND_MAGAZINES
# 7134                        Football-CB GO Clock Theme     PERSONALIZATION
# 2893                             Camera ZOOM FX - FREE         PHOTOGRAPHY
# 2583                                            Moment              SOCIAL
# 5611                                CM FILE MANAGER HD        PRODUCTIVITY
# 1146  Moneycontrol – Stocks, Sensex, Mutual Funds, IPO             FINANCE
#
#       Rating Reviews                Size     Installs  Type Price  \
# 8026     4.2    6784                 13M     500,000+  Free     0
# 2493     4.6    2014                 69M      50,000+  Free     0
# 8416     3.8     168                 24M      10,000+  Free     0
# 9366     4.6      10                8.7M       1,000+  Free     0
# 8028     4.2    1137                 11M      50,000+  Free     0
# 7134     4.7      26                5.6M       1,000+  Free     0
# 2893     4.0   88860                6.1M   5,000,000+  Free     0
# 2583     4.5   19583                 37M   1,000,000+  Free     0
# 5611     4.3  144873  Varies with device  10,000,000+  Free     0
# 1146     4.4  281485  Varies with device   5,000,000+  Free     0
#
#      Content Rating            Genres      Last Updated         Current Ver  \
# 8026       Everyone     Entertainment   August 30, 2017               2.3.0
# 2493       Everyone           Medical    August 3, 2018            6.02.000
# 8416       Everyone          Strategy     March 1, 2017               1.2.2
# 9366       Everyone         Lifestyle     July 18, 2018               7.2.2
# 8028       Everyone  News & Magazines     July 23, 2018               5.5.0
# 7134       Everyone   Personalization     March 3, 2017               1.0.3
# 2893       Everyone       Photography     April 6, 2017               6.2.9
# 2583           Teen            Social    August 1, 2018               5.2.1
# 5611       Everyone      Productivity  January 24, 2016               3.5.0
# 1146       Everyone           Finance      May 11, 2018  Varies with device
#
#              Android Ver
# 8026          4.4 and up
# 2493          6.0 and up
# 8416        4.0.3 and up
# 9366          4.1 and up
# 8028          4.3 and up
# 7134        4.0.3 and up
# 2893          2.3 and up
# 2583          4.4 and up
# 5611  Varies with device
# 1146  Varies with device

# %% [markdown]
# ## EDA

# %%
df = googleplaystore.copy()
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                     Genres      Last Updated  \
# 0           Everyone               Art & Design   January 7, 2018
# 1           Everyone  Art & Design;Pretend Play  January 15, 2018
# 2           Everyone               Art & Design    August 1, 2018
# 3               Teen               Art & Design      June 8, 2018
# 4           Everyone    Art & Design;Creativity     June 20, 2018
# ...              ...                        ...               ...
# 10836       Everyone                  Education     July 25, 2017
# 10837       Everyone                  Education      July 6, 2018
# 10838       Everyone                    Medical  January 20, 2017
# 10839     Mature 17+          Books & Reference  January 19, 2015
# 10840       Everyone                  Lifestyle     July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# ## Data Preprocessing

# %%
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9360 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9360 non-null   object
#  1   Category        9360 non-null   object
#  2   Rating          9360 non-null   float64
#  3   Reviews         9360 non-null   object
#  4   Size            9360 non-null   object
#  5   Installs        9360 non-null   object
#  6   Type            9360 non-null   object
#  7   Price           9360 non-null   object
#  8   Content Rating  9360 non-null   object
#  9   Genres          9360 non-null   object
#  10  Last Updated    9360 non-null   object
#  11  Current Ver     9360 non-null   object
#  12  Android Ver     9360 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1023.8+ KB

# %% [markdown]
# ## Strorytelling - Visualization

# %% [markdown]
# ## Send us the Result (Maktabkhoone)
